# %% [markdown]
# ## Chapter Two Hints

# %% [markdown]
# ## <font color='green'>Create A Date</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1.   Create the date object <font color='green'>vets_day_2025</font>.
# 2.   Use dot notation to access the attributes.
# 3.   Display results as an f string.

# %% [markdown]
# ## <font color='green'>Get The Last Day Of The Month</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1. Create date objects: e.g. feb_2024
# 2. Use <font color='green'>monthrange</font>
# 3. Display results with f string.

# %% [markdown]
# ## <font color='green'>Add Six Months To A Date</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
#
# 1.   Create the data object <font color='green'>june_2025_last</font>
# 2.   Use <font color='green'>relativedelta</font>.to add six months.

# %% [markdown]
# ## <font color='green'>Access Bonds With Specific Characteristics</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1. Assume that 'Matrity Date' column is a Pandas Timestamp equivalent to datetime object.
# 2. Convert the index (a datetime object) to a date object
# 3. After creating the DataFrame of 304 bonds, use the loc attribute to create a DataFrame with maturity dates in the list of date objects.
# 4.  Use the loc attribute of the DataFrame matching maturities to select those bonds with coupons greater than 3.5.

# %% [markdown]
# ## <font color='green'>Calculate Days For Accrued Interst</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
#
#
# 1.   Import date from datetime
# 2.   Import  <font color='green'>relativedelta</font> from dateutil
# 3.   Import requests
# 3.   Import  <font color='green'>scheduled_pay_dates</font> from the custom module.
# 4.   Get  <font color='green'>next_coupon_date</font> from <font color='green'>scheduled_pay_dates</font>
# 5.   Calculate <font color='green'>last_coupon_date</font> by subtracting six months from <font color='green'>next_coupon_date</font>
# 6.  Subtract date objects as needed and display the days attribute.

# %% [markdown]
# ## <font color='green'>Calculate A Transaction Price</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1.   Create  date objects <font color='green'>maturity_date</font> and <font color='green'>settlement_date</font>
# 2.   Import <font color='green'>accrued_interest</font> from the custom module
# 2.   Pass date objects and coupon to <font color='green'>accrued_interest</font>
# 3.   Add accrued interest to clean price

# %% [markdown]
# ## <font color='green'>Create An Excel Workbook</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1.   Use the iloc attribute of the bond_data DataFrame to create a DataFrame with the first ten roww.
# 2.   Use the <font color='green'>create_workbook</font> to create an Excel workbook.
# 3.  <font color='green'>save_config</font> defaults to an empty dictionary

# %% [markdown]
# ## <font color='green'>Chapter Two Exercise</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1.   Get fresh copy of <font color='green'>bond_data</font> from DropBox
# 2.   Use  <font color='green'>iloc</font> with the <font color='green'>copy</font> method to create a DataFrame <font color='green'>first_100_rows</font> unrelated to <font color='green'>bond_data</font>.
# 3.   Use the Pandas <font color='green'>apply</font> method to update the DataFrame with <font color='green'>accrured_interest function</font>.
