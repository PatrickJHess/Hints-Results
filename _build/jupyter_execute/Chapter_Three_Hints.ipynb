# %% [markdown]
# ## Chapter Three Hints

# %% [markdown]
# ## <font color='green'>Application: Find a holiday</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1.   Import and if necessary install holidays
# 2.   Assign USA with dot notation.
# 3.   Use list comprehension with items() method and condition for values

# %% [markdown]
# ## <font color='green'>Calculate Payment Date</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
# 1. Import and if necessary install modules
# 2. Create a dictionary of non settlement days for 2026 and 2028
# 3. Use while loop to check if dates are in non settlement dictionary or a weekend

# %% [markdown]
# ## <font color='green'>Application: Calculate Payment Dates And Day Of The Week For Five Scheduled Payment Dates</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
#
#
#
#
# *   Create a non-settlement dictionary for 2027, 2028, 2029, and 2030
# *   Import <font color='green'>adjust_bond_pay_date</font> from *basic_concepts_of_fixed_income* module.
# *   Import Pandas
# *   From a list or other iterable of the scheduled payment dates, create a Pandas series.
# *   Calculate payment dates by applying <font color='green'>adjust_bond_pay_date</font> to the Pandas series.
# *   Calculate days of the week by applying a lambda function <font color='green'>date_value.weekday()</font>

# %% [markdown]
# ## <font color='green'> Chapter Three Exercise</font>

# %% [markdown]
# <div style="background-color:LightGray;
#     border-left: 12px solid green;
#     font-family: 'Garamond', serif;
#     font-size: 17px;
#     line-height: 1.5;
#     padding: 15px">
# <br>
#
# 1.   Create a list of date objects.
# 2.   Create a list of coupon amounts
# 3.   Create a dictionary with keys equal to maturity and values coupon amount
# 4.   Make settlement equal to the date object for January 21$^{st}$ 2025.
# 5.   Iterate through the dictionary with <font color='green'>items()</font> method of dictionaries.
# 6.   Make the keys, values, and settlement the arguments of <font color='green'>bond_pay_data()</font> and display the results for each iteration.
#
#
#
# **If you are unfamiliar with the <font color='green'>items()</font> method of dictionaries** [take a look at the background material.](https://patrickjhess.github.io/Introduction-To-Python-For-Financial-Python/Dictionaries.html#the-items-method-equivalent-to-zip-of-keys-and-values)
